# %% [markdown]
# # <center> Shri Ramdeobaba College of Engineering and Management, Nagpur</center>
# ## <center>Department of Computer Science Engineering</center>
# ## <center>Python Programming LAB (CAP 201) (2021-2022)</center>
# ## <center>Practical Assignment 06</center>
#
# ---

# %% [markdown]
# #### <strong>Name : </strong> <em>Shantanu Mane</em>
# #### <strong>Roll Number : </strong> <em>63 (E-4)</em>
# #### <strong>Section : </strong> <em>E (AIML)</em>
# #### <strong>Date : </strong> <em>30<sup>th</sup> January 2022</em>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto_df = pd.read_csv('./Automobile_data.csv')

# %%
auto_df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
auto_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
auto_df.shape
# Out:
# (205, 26)

# %%
auto_df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
auto_df.head(4)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# ...

# %%
auto_df.tail(4)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 201         mpfi  3.78    3.15               8.7        160      5300
# 202         mpfi  3.58    2.87               8.8        134      5500
# ...

# %%
auto_df.loc[auto_df["symboling"] == '?']
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
columns = list(auto_df.columns)
columns
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
columns = list(auto_df.columns)

for column in columns:
    auto_df[column].loc[auto_df[column] == '?'] = None
# Out:
# C:\Python39\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
auto_df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0              None  alfa-romero       gas        std
# 1          3.0              None  alfa-romero       gas        std
# 2          1.0              None  alfa-romero       gas        std
# 3          2.0               164         audi       gas        std
# 4          2.0               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo       gas        std
# 201       -1.0                95        volvo       gas      turbo
# 202       -1.0                95        volvo       gas        std
# 203       -1.0                95        volvo    diesel      turbo
# 204       -1.0                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
auto_df.describe(include='all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               164     205       205        205
# unique         NaN                51      22         2          2
# top            NaN               161  toyota       gas        std
# freq           NaN                11      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           203        205          205             205  205.000000  ...
# ...

# %%
rows = len(auto_df.index)
col = len(auto_df.columns)

# %%
print(f"Rows : {rows}\nColumns : {col}")
# Out:
# Rows : 205
# Columns : 26

# %%
auto_df.groupby('make')[['normalized-losses','fuel-type','aspiration','num-of-doors','body-style',
 'drive-wheels',
 'engine-location',
 'wheel-base',
 'length',
 'width',
 'height',
 'curb-weight',
 'engine-type',
 'num-of-cylinders',
 'engine-size',
 'fuel-system',
 'bore',
 'stroke',
 'compression-ratio',
 'horsepower',
 'peak-rpm',
 'city-mpg',
 'highway-mpg',
 'price']].mean()
# Out:
#                wheel-base      length      width     height  curb-weight  \
# make
# alfa-romero     90.566667  169.600000  64.566667  50.000000  2639.666667
# audi           102.271429  183.828571  68.714286  54.428571  2800.714286
# bmw            103.162500  184.500000  66.475000  54.825000  2929.375000
# chevrolet       92.466667  151.933333  62.500000  52.400000  1757.000000
# dodge           95.011111  160.988889  64.166667  51.644444  2151.333333
# honda           94.330769  160.769231  64.384615  53.238462  2096.769231
# isuzu           94.825000  163.775000  63.550000  52.225000  2213.500000
# jaguar         109.333333  196.966667  69.933333  51.133333  4027.333333
# mazda           97.017647  170.805882  65.588235  53.358824  2297.823529
# mercedes-benz  110.925000  195.262500  71.062500  55.725000  3696.250000
# mercury        102.700000  178.400000  68.000000  54.800000  2910.000000
# mitsubishi      95.353846  168.030769  65.253846  50.692308  2381.923077
# ...

# %%
auto_df.groupby('make')[['normalized-losses','fuel-type','aspiration','num-of-doors','body-style',
 'drive-wheels',
 'engine-location',
 'wheel-base',
 'length',
 'width',
 'height',
 'curb-weight',
 'engine-type',
 'num-of-cylinders',
 'engine-size',
 'fuel-system',
 'bore',
 'stroke',
 'compression-ratio',
 'horsepower',
 'peak-rpm',
 'city-mpg',
 'highway-mpg',
 'price']].std()
# Out:
#                wheel-base     length     width    height  curb-weight  \
# make
# alfa-romero      3.406367   1.385641  0.808290  2.078461   158.771324
# audi             3.303894   8.315791  2.575803  1.477288   280.549291
# bmw              2.988042   8.622230  2.177646  0.931589   428.755987
# chevrolet        3.521837   9.493331  1.905256  0.692820   233.617208
# dodge            3.192352   7.328275  0.842615  3.063948   320.698067
# honda            3.632810  11.879210  0.918192  1.991038   241.223670
# isuzu            0.788987   9.126290  1.389244  0.895824   405.854243
# jaguar           6.350853   4.561067  0.577350  2.886751    66.972631
# mazda            3.806776   7.004059  0.974604  2.236084   269.747390
# mercedes-benz    7.261788   9.336401  0.770783  2.279568   133.944285
# mercury               NaN        NaN       NaN       NaN          NaN
# mitsubishi       1.291392   7.452671  0.801681  0.785771   341.663934
# ...

# %%
auto_df.groupby('make')[['normalized-losses','fuel-type','aspiration','num-of-doors','body-style',
 'drive-wheels',
 'engine-location',
 'wheel-base',
 'length',
 'width',
 'height',
 'curb-weight',
 'engine-type',
 'num-of-cylinders',
 'engine-size',
 'fuel-system',
 'bore',
 'stroke',
 'compression-ratio',
 'horsepower',
 'peak-rpm',
 'city-mpg',
 'highway-mpg',
 'price']].var()
# Out:
#                wheel-base      length      width     height    curb-weight  \
# make
# alfa-romero     11.603333    1.920000   0.653333   4.320000   25208.333333
# audi            10.915714   69.152381   6.634762   2.182381   78707.904762
# bmw              8.928393   74.342857   4.742143   0.867857  183831.696429
# chevrolet       12.403333   90.123333   3.630000   0.480000   54577.000000
# dodge           10.191111   53.703611   0.710000   9.387778  102847.250000
# honda           13.197308  141.115641   0.843077   3.964231   58188.858974
# isuzu            0.622500   83.289167   1.930000   0.802500  164717.666667
# jaguar          40.333333   20.803333   0.333333   8.333333    4485.333333
# mazda           14.491544   49.056838   0.949853   5.000074   72763.654412
# mercedes-benz   52.733571   87.168393   0.594107   5.196429   17941.071429
# mercury               NaN         NaN        NaN        NaN            NaN
# ...

# %%
auto_df.groupby('make')[['normalized-losses','fuel-type','aspiration','num-of-doors','body-style',
 'drive-wheels',
 'engine-location',
 'wheel-base',
 'length',
 'width',
 'height',
 'curb-weight',
 'engine-type',
 'num-of-cylinders',
 'engine-size',
 'fuel-system',
 'bore',
 'stroke',
 'compression-ratio',
 'horsepower',
 'peak-rpm',
 'city-mpg',
 'highway-mpg',
 'price']].skew()
# Out:
# C:\Python39\lib\site-packages\pandas\core\groupby\groupby.py:936: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return f(x, *args, **kwargs)
#                normalized-losses  wheel-base    length     width    height  \
# make
# alfa-romero                  NaN    1.732051  1.732051  1.732051  1.732051
# audi                    0.000000    0.366507  0.358124  0.207734 -0.678614
# bmw                     0.000000    2.067265  0.330911  1.307635  0.599887
# chevrolet               0.443872   -1.732051 -1.551995 -1.732051  1.732051
# dodge                  -0.343635    2.738802  1.629810  2.537373  2.978499
# honda                   0.742061   -1.731991 -0.096892 -0.111832  1.155467
# isuzu                        NaN    1.912371  0.037400 -0.215572  1.380237
# ...

# %%
temp = 0

for i in range(205):
    if auto_df.price[i] is not None:
        temp = auto_df.price[i]
        temp = int(temp)
        auto_df.price[i] = temp
# Out:
# C:\Users\SHANTANU\AppData\Local\Temp/ipykernel_33432/1407542389.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   auto_df.price[i] = temp

# %%
auto_df.loc[auto_df.price == auto_df.price.max()]
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 74        1.0              None  mercedes-benz       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 74          two    hardtop          rwd           front       112.0  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 74        304.0         mpfi   3.8    3.35               8.0        184
#
#     peak-rpm city-mpg highway-mpg  price
# 74      4500     14.0        16.0  45400
#
# [1 rows x 26 columns]

# %%
auto_df.loc[auto_df.make == 'toyota']
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 150        1.0                87  toyota       gas        std          two
# 151        1.0                87  toyota       gas        std          two
# 152        1.0                74  toyota       gas        std         four
# 153        0.0                77  toyota       gas        std         four
# 154        0.0                81  toyota       gas        std         four
# 155        0.0                91  toyota       gas        std         four
# 156        0.0                91  toyota       gas        std         four
# 157        0.0                91  toyota       gas        std         four
# 158        0.0                91  toyota    diesel        std         four
# 159        0.0                91  toyota    diesel        std         four
# 160        0.0                91  toyota       gas        std         four
# ...

# %%
auto_df.groupby('make')['price'].max()
# Out:
# make
# alfa-romero      16500
# audi             23875
# bmw              41315
# chevrolet         6575
# dodge            12964
# honda            12945
# isuzu            11048
# jaguar           36000
# mazda            18344
# mercedes-benz    45400
# mercury          16503
# mitsubishi       14869
# nissan           19699
# peugot           18150
# plymouth         12764
# porsche          37028
# renault           9895
# saab             18620
# subaru           11694
# toyota           17669
# volkswagen       13845
# volvo            22625
# Name: price, dtype: int64

# %%
auto_df.groupby('make')[['city-mpg','highway-mpg']].max()
# Out:
#                city-mpg  highway-mpg
# make
# alfa-romero        21.0         27.0
# audi               24.0         30.0
# bmw                23.0         29.0
# chevrolet          47.0         53.0
# dodge              37.0         41.0
# honda              49.0         54.0
# isuzu              38.0         43.0
# jaguar             15.0         19.0
# mazda              36.0         42.0
# mercedes-benz      22.0         25.0
# mercury            19.0         24.0
# mitsubishi         37.0         41.0
# nissan             45.0         50.0
# peugot             28.0         33.0
# plymouth           37.0         41.0
# porsche            19.0         28.0
# renault            23.0         31.0
# saab               21.0         28.0
# subaru             32.0         37.0
# toyota             38.0         47.0
# volkswagen         37.0         46.0
# volvo              26.0         28.0

# %%
auto_df.sort_values('price')
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 138        2.0                83         subaru       gas        std
# 18         2.0               121      chevrolet       gas        std
# 50         1.0               104          mazda       gas        std
# 150        1.0                87         toyota       gas        std
# 76         2.0               161     mitsubishi       gas        std
# ..         ...               ...            ...       ...        ...
# 74         1.0              None  mercedes-benz       gas        std
# 9          0.0              None           audi       gas      turbo
# 44         1.0              None          isuzu       gas        std
# 45         0.0              None          isuzu       gas        std
# 129        1.0              None        porsche       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
plt.figure(figsize=(20,10))

plt.barh(auto_df.index, auto_df['length'])
plt.barh(auto_df.index, auto_df['wheel-base'])
plt.barh(auto_df.index, auto_df['width'])
plt.barh(auto_df.index, auto_df['height'])

plt.legend(['Length', 'Wheel - Base', 'Width', 'Height'])

plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(auto_df.index, auto_df['length'])
plt.plot(auto_df.index, auto_df['wheel-base'])
plt.plot(auto_df.index, auto_df['width'])
plt.plot(auto_df.index, auto_df['height'])

plt.legend(['Length', 'Wheel - Base', 'Width', 'Height'])

plt.show()

# %%
plt.figure(figsize=(30,10))

plt.scatter(auto_df.index, auto_df['length'])
plt.scatter(auto_df.index, auto_df['wheel-base'])
plt.scatter(auto_df.index, auto_df['width'])
plt.scatter(auto_df.index, auto_df['height'])

plt.legend(['Length', 'Wheel - Base', 'Width', 'Height'])

plt.show()

# %%
auto_df.corr(method='pearson')
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel-base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb-weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine-size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression-ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# city-mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway-mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# symboling            -0.227691    -0.105790          -0.178515 -0.035823
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(auto_df.corr(),cmap='icefire')
# Out:
# <AxesSubplot:>
