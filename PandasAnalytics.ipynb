# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.3.2

# %%
myData = {
    "cars": ["BMW", "Mercedes", "Audi"],
    "sales" : [3,7,2]   #in million units
}

df = pd.DataFrame(myData)

df
# Out:
#        cars  sales
# 0       BMW      3
# 1  Mercedes      7
# 2      Audi      2

# %%
linData = [2,5,3,6]

df = pd.Series(linData, index=["x","y","z","t"])

df
# Out:
# x    2
# y    5
# z    3
# t    6
# dtype: int64

# %%
df["y"]
# Out:
# 5

# %%
calData = {
    'Day_1': 310,
    'Day_2': 280,
    'Day_3': 290,
    'Day_4': 300
}

df = pd.Series(calData)
df
# Out:
# Day_1    310
# Day_2    280
# Day_3    290
# Day_4    300
# dtype: int64

# %%
calData = {
    'Day': ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'],
    'Calories' : [308,342,243,278,312,320]
}

df = pd.DataFrame(calData,index=['Day-1','Day-2','Day-3','Day-4','Day-5','Day-6'])

df
# Out:
#              Day  Calories
# Day-1     Monday       308
# Day-2    Tuesday       342
# Day-3  Wednesday       243
# Day-4   Thursday       278
# Day-5     Friday       312
# Day-6   Saturday       320

# %%
print(df.loc['Day-1'])
# Out:
# Day         Monday
# Calories       308
# Name: Day-1, dtype: object

# %%
print(df.loc[[0,1,2]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/2261765736.py in <module>
# ----> 1 print(df.loc[[0,1,2]])
#
# C:\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# C:\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# C:\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
# ...

# %%
calData2 = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(calData2, index = ["day1", "day2", "day3"])

df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df.loc["day2"]
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
df['calories']
# Out:
# day1    420
# day2    380
# day3    390
# Name: calories, dtype: int64

# %%
df = pd.read_csv('../gapminder-FiveYearData.csv')

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# year           int64
# pop          float64
# continent     object
# lifeExp      float64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
country_df = df['country']

# %%
country_df
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df.tail()
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
subset = df[['country','continent','year']]

subset
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[0]
# Out:
# country      Afghanistan
# year                1952
# pop            8425333.0
# continent           Asia
# lifeExp           28.801
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[99]
# Out:
# country      Bangladesh
# year               1967
# pop          62821884.0
# continent          Asia
# lifeExp          43.453
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
df.tail(n=5)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.tail(n=3)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
df.tail(n=1)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
# first, 10th, 100th and 1000th row

df.loc[[0,9,99,999]]
# Out:
#          country  year         pop continent  lifeExp    gdpPercap
# 0    Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 9    Afghanistan  1997  22227415.0      Asia   41.763   635.341351
# 99    Bangladesh  1967  62821884.0      Asia   43.453   721.186086
# 999     Mongolia  1967   1149500.0      Asia   51.253  1226.041130

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# year                1952
# pop            8425333.0
# continent           Asia
# lifeExp           28.801
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# country      Afghanistan
# year                1957
# pop            9240934.0
# continent           Asia
# lifeExp           30.332
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
df.iloc[99]
# Out:
# country      Bangladesh
# year               1967
# pop          62821884.0
# continent          Asia
# lifeExp          43.453
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
df.iloc[-1]
# Out:
# country        Zimbabwe
# year               2007
# pop          12311143.0
# continent        Africa
# lifeExp          43.487
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.iloc[-3]
# Out:
# country        Zimbabwe
# year               1997
# pop          11404948.0
# continent        Africa
# lifeExp          46.809
# gdpPercap     792.44996
# Name: 1701, dtype: object

# %%
df.iloc[[0,9,99,999]]
# Out:
#          country  year         pop continent  lifeExp    gdpPercap
# 0    Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 9    Afghanistan  1997  22227415.0      Asia   41.763   635.341351
# 99    Bangladesh  1967  62821884.0      Asia   43.453   721.186086
# 999     Mongolia  1967   1149500.0      Asia   51.253  1226.041130

# %%
df.loc[:]
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[:,['country','pop','lifeExp']]
# Out:
#           country         pop  lifeExp
# 0     Afghanistan   8425333.0   28.801
# 1     Afghanistan   9240934.0   30.332
# 2     Afghanistan  10267083.0   31.997
# 3     Afghanistan  11537966.0   34.020
# 4     Afghanistan  13079460.0   36.088
# ...           ...         ...      ...
# 1699     Zimbabwe   9216418.0   62.351
# 1700     Zimbabwe  10704340.0   60.377
# 1701     Zimbabwe  11404948.0   46.809
# 1702     Zimbabwe  11926563.0   39.989
# 1703     Zimbabwe  12311143.0   43.487
#
# [1704 rows x 3 columns]

# %%
df.iloc[:,[1,2,3]]
# Out:
#       year         pop continent
# 0     1952   8425333.0      Asia
# 1     1957   9240934.0      Asia
# 2     1962  10267083.0      Asia
# 3     1967  11537966.0      Asia
# 4     1972  13079460.0      Asia
# ...    ...         ...       ...
# 1699  1987   9216418.0    Africa
# 1700  1992  10704340.0    Africa
# 1701  1997  11404948.0    Africa
# 1702  2002  11926563.0    Africa
# 1703  2007  12311143.0    Africa
#
# [1704 rows x 3 columns]

# %%
df.iloc[:,[2,4,-1]]
# Out:
#              pop  lifeExp   gdpPercap
# 0      8425333.0   28.801  779.445314
# 1      9240934.0   30.332  820.853030
# 2     10267083.0   31.997  853.100710
# 3     11537966.0   34.020  836.197138
# 4     13079460.0   36.088  739.981106
# ...          ...      ...         ...
# 1699   9216418.0   62.351  706.157306
# 1700  10704340.0   60.377  693.420786
# 1701  11404948.0   46.809  792.449960
# 1702  11926563.0   39.989  672.038623
# 1703  12311143.0   43.487  469.709298
#
# [1704 rows x 3 columns]

# %%
df.iloc[:,range(3)]
# Out:
#           country  year         pop
# 0     Afghanistan  1952   8425333.0
# 1     Afghanistan  1957   9240934.0
# 2     Afghanistan  1962  10267083.0
# 3     Afghanistan  1967  11537966.0
# 4     Afghanistan  1972  13079460.0
# ...           ...   ...         ...
# 1699     Zimbabwe  1987   9216418.0
# 1700     Zimbabwe  1992  10704340.0
# 1701     Zimbabwe  1997  11404948.0
# 1702     Zimbabwe  2002  11926563.0
# 1703     Zimbabwe  2007  12311143.0
#
# [1704 rows x 3 columns]

# %%
df.loc[42,'country']
# Out:
# 'Angola'

# %%
df.iloc[42,0]
# Out:
# 'Angola'

# %%
df.loc[0:1700:50,['country']]
# Out:
#                      country
# 0                Afghanistan
# 50                 Argentina
# 100               Bangladesh
# 150   Bosnia and Herzegovina
# 200             Burkina Faso
# 250                   Canada
# 300                 Colombia
# 350               Costa Rica
# 400           Czech Republic
# 450                  Ecuador
# 500                  Eritrea
# 550                    Gabon
# 600                Guatemala
# 650                 Honduras
# 700                    India
# 750                  Ireland
# 800                    Japan
# 850               Korea Rep.
# 900                    Libya
# 950                     Mali
# 1000                Mongolia
# 1050                 Myanmar
# 1100             New Zealand
# 1150                  Norway
# 1200                    Peru
# 1250             Puerto Rico
# 1300   Sao Tome and Principe
# 1350            Sierra Leone
# 1400                 Somalia
# 1450                   Sudan
# 1500                  Taiwan
# ...

# %%
df.loc[10:13,['country','lifeExp',"gdpPercap"]]
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %%
df.head(n=10)
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
multi_group_var = df.groupby(['year','continent'])[['lifeExp',"gdpPercap"]].mean()
multi_group_var
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
multi_group_var.reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %% [markdown]
# ### use the nunique to get counts of unique values on a Pandas Series.

# %%
df.groupby('continent')['country'].nunique()    #! Unique countries in each continent
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
global_yearly_life_expectancy
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
global_yearly_life_expectancy.plot(color='r')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
Average_Global_GDP_growth_per_year = df.groupby('year')['gdpPercap'].mean().plot(color='magenta')
